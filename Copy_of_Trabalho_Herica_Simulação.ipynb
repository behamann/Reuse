# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/jbrunoxd/Reuse/blob/master/Copy_of_Trabalho_Herica_Simula%C3%A7%C3%A3o.ipynb)

# %%
print("Hello World");
# Out:
# Hello World

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d7647a10-2b71-4ee6-aa66-8cac0173654f" name="files[]" multiple disabled />
#      <output id="result-d7647a10-2b71-4ee6-aa66-8cac0173654f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving clientes.csv to clientes.csv

# %%
import io
data = io.BytesIO(uploaded['clientes.csv'])

# %%
import pandas as pd   
df = pd.read_csv(data, sep=';')
df.head()
# Out:
#    cliente perfil  valor_total_ticket  idade  renda_sm  recorrencia
# 0        1      b                5952     24       3.9           50
# 1        2      c                7676     34       7.5           52
# 2        3      b                5809     24       3.0           45
# 3        4      b                7004     31       4.2           38
# 4        5      c                6271     25       4.8           53

# %%
df.assign(ticket_medio=df.valor_total_ticket/df.recorrencia)
# Out:
#         cliente perfil  valor_total_ticket  idade  renda_sm  recorrencia  \
# 0             1      b                5952     24       3.9           50
# 1             2      c                7676     34       7.5           52
# 2             3      b                5809     24       3.0           45
# 3             4      b                7004     31       4.2           38
# 4             5      c                6271     25       4.8           53
# 5             6      b                5149     22       5.1           38
# 6             7      b                4967     23       3.6           41
# 7             8      c                7192     28       4.8           63
# 8             9      b                6261     28       5.1           40
# 9            10      b                6437     33       3.0           43
# 10           11      c                6541     28       6.3           60
# 11           12      b                6598     24       3.6           37
# ...

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ea8415b8a3ee> in <module>()
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined
